# %% [markdown]
# Script to output the U100 data for the VWIND constraint for CMIP6.  This includes ensemble mean 100hPa zonal mean zonal wind averaged from 20N to 40N for the future-past difference for the ensemble mean and for 1 mem.

# %%
import importlib
import pandas as pd
import xarray as xr
import numpy as np
import xesmf as xe
from numpy import nan
import sys
import warnings
import math
from glob import glob

from ecpaper_utils import readdata_utils as read
from ecpaper_utils import calendar_utils as cal
from ecpaper_utils import averaging_utils as avg

importlib.reload(read)
importlib.reload(cal)
importlib.reload(avg)

warnings.filterwarnings('ignore')

# %% [markdown]
# Set paths for CMIP6 models (historical and RCP8.5) and the pressure level to us (in Pa)

# %%
histpath="/project/cmip6/historical/Amon/"
rcp85path="/project/cmip6/ssp585/Amon/"
plevuse="10000"
pathout="/project/cas/islas/python/ecpaper2020/DATASORT/VWIND/DATA/"

# %% [markdown]
# Information ont he models being used is provided in cmip5csvinfo.csv.  This contains information on the models, number of members and whether there's any special order for the member numbers i.e., if they don't simply go from 1 to N.  Read in this info and set up the dates for each period.

# %%
cmip6models=pd.read_csv("../cmip6csvinfo.csv")

ybegp = 1979 ; monbegp = 1 ; yendp = 2014 ; monendp = 12 # dates for past period
ybegf = 2070 ; monbegf = 1 ; yendf = 2099 ; monendf = 12 # dates for Future period

# total number of months (used for checking)
nmonthsp = (yendp-ybegp-1)*12 + (12-monbegp+1) + monendp
nmonthsf = (yendf-ybegf-1)*12 + (12-monbegf+1) + monendf

# set up date names
datebegp=str(ybegp)+"-"+str(monbegp).zfill(2)
dateendp=str(yendp)+"-"+str(monendp).zfill(2)
datebegf=str(ybegf)+"-"+str(monbegf).zfill(2)
dateendf=str(yendf)+"-"+str(monendf).zfill(2)

# %%
models=cmip6models["Model"]
nmodels=models.size

# define 1 deg greid
grid_out = xr.Dataset({'lat': (['lat'], np.arange(-90,91,1.0)), 'lon': (['lon'], np.arange(0,360,1.0))})
nlon = grid_out["lon"].size ; nlat=grid_out["lat"].size

# define multi-model arrays
upast_em = xr.DataArray(np.zeros([nmodels,nlat]), coords=[models, grid_out['lat']], dims=['Model', 'lat'], name='upast_em')
upast_1mem = xr.DataArray(np.zeros([nmodels,nlat]), coords=[models, grid_out['lat']], dims=['Model', 'lat'], name='upast_1mem')
ufut_em = xr.DataArray(np.zeros([nmodels,nlat]), coords=[models, grid_out['lat']], dims=['Model', 'lat'], name='ufut_em')
ufut_1mem = xr.DataArray(np.zeros([nmodels,nlat]), coords=[models, grid_out['lat']], dims=['Model', 'lat'], name='ufut_1mem')
# loop over models
for index, modname in models.iteritems():
    
    # ---- the past period ----
    nmems=cmip6models.loc[index, "Nmempast"]
    ftype=cmip6models.loc[index, "ftypep"]
    ptype=cmip6models.loc[index, "ptype"]
    
    for imem in range(1, nmems+1, 1): # loop over members
        if (math.isnan(ptype)):
            memstr="r"+str(imem)+"i1p1f"+str(int(ftype))
        else:
            memstr="r"+str(imem)+"i1p"+str(int(ptype))+"f"+str(int(ftype))
            
                    
        # check for a special order
        changeorder = cmip6models.loc[index, "specialorderpast"]
        if (type(changeorder) == str):
            changeordernp=np.array(changeorder.split(","))
            if (math.isnan(ptype)):
                memstr="r"+str(changeordernp[imem-1])+"i1p1f"+str(int(ftype))
            else:
                memstr="r"+str(changeordernp[imem-1])+"i1p"+str(int(ptype))+"f"+str(int(ftype))
            
        print("Processing past for "+modname+" "+memstr+"...")
        histdir=glob(histpath+"ua/"+modname+"/"+memstr+"/*/")
        histdir=histdir[0]
        print(histdir)
        
        # read in meridional wind, concatenate historical to 2005, rcp85 to 2014
        u = read.read_zonalmean_1lev(histdir+"/*.nc", datebegp, dateendp, plevuse) 
            
        # check again
        if (u.time.size != nmonthsp):
            print("something's wrong, nmonthsp="+str(nmonthsp)+" but u has size "+str(v.time.size))
            sys.exit("u past for "+modname+", "+memstr+" doesn't have the right size")
            
        # calculate DJF mean and interpolate
        udjf = cal.season_mean(u, "ua", season="DJF")
        udjf = udjf.dropna('lat')
        udjfinterp = udjf.interp(lat=np.linspace(-90,90,181), method="cubic")
        
        if (imem == 1):
            upast_1mem[index,:] = udjfinterp
            
        upast_em[index,:] = upast_em[index,:] + udjfinterp[:]/float(nmems)
        
    # ---the future period-------
    
    nmems=cmip6models.loc[index, "Nmemfuture"]
    ftype=cmip6models.loc[index, "ftypef"]
    for imem in range(1,nmems+1,1):
        if (math.isnan(ptype)):
            memstr="r"+str(imem)+"i1p1f"+str(int(ftype))
        else:
            memstr="r"+str(imem)+"i1p"+str(int(ptype))+"f"+str(int(ftype))
        
        changeorder=cmip6models.loc[index,"specialorderfuture"]
        if (type(changeorder) == str):
            changeordernp=np.array(changeorder.split(","))
            if (math.isnan(ptype)):
                memstr="r"+str(changeordernp[imem-1])+"i1p1f"+str(int(ftype))
            else:
                memstr="r"+str(changeordernp[imem-1])+"i1p"+str(int(ptype))+"f"+str(int(ftype))
            
        print("Processing future for "+modname+" "+memstr)
        rcp85dir=glob(rcp85path+"/ua/"+modname+"/"+memstr+"/*/")
        rcp85dir=rcp85dir[0]
        u=read.read_zonalmean_1lev(rcp85dir+"/*.nc", datebegf, dateendf, plevuse)
        
        # check the right number of months are there
        if (u.time.size != nmonthsf):
            print("something's wrong, nmonthf="+str(nmonthsf)+" but u has size "+str(v.time.size))
            sys.exit("u future for "+modname+", "+memstr+" doesn't have the right size")
            
        udjf = cal.season_mean(u, "ua", season="DJF")
        udjf = udjf.dropna('lat')
        udjfinterp = udjf.interp(lat=np.linspace(-90,90,181), method="cubic")
        
        if (imem == 1):
            ufut_1mem[index,:]=udjfinterp
            
        ufut_em[index,:] = ufut_em[index,:] + udjfinterp[:]/float(nmems)
# Out:
# Processing past for ACCESS-CM2 r1i1p1f1...
# /project/cmip6/historical/Amon/ua/ACCESS-CM2/r1i1p1f1/gn/
# Processing past for ACCESS-CM2 r2i1p1f1...
# /project/cmip6/historical/Amon/ua/ACCESS-CM2/r2i1p1f1/gn/
# Processing future for ACCESS-CM2 r1i1p1f1
# Processing past for ACCESS-ESM1-5 r1i1p1f1...
# /project/cmip6/historical/Amon/ua/ACCESS-ESM1-5/r1i1p1f1/gn/
# Processing past for ACCESS-ESM1-5 r2i1p1f1...
# /project/cmip6/historical/Amon/ua/ACCESS-ESM1-5/r2i1p1f1/gn/
# Processing past for ACCESS-ESM1-5 r3i1p1f1...
# /project/cmip6/historical/Amon/ua/ACCESS-ESM1-5/r3i1p1f1/gn/
# Processing future for ACCESS-ESM1-5 r1i1p1f1
# Processing future for ACCESS-ESM1-5 r2i1p1f1
# Processing future for ACCESS-ESM1-5 r3i1p1f1
# Processing past for AWI-CM-1-1-MR r1i1p1f1...
# /project/cmip6/historical/Amon/ua/AWI-CM-1-1-MR/r1i1p1f1/gn/
# Processing past for AWI-CM-1-1-MR r2i1p1f1...
# /project/cmip6/historical/Amon/ua/AWI-CM-1-1-MR/r2i1p1f1/gn/
# Processing past for AWI-CM-1-1-MR r3i1p1f1...
# /project/cmip6/historical/Amon/ua/AWI-CM-1-1-MR/r3i1p1f1/gn/
# Processing past for AWI-CM-1-1-MR r4i1p1f1...
# /project/cmip6/historical/Amon/ua/AWI-CM-1-1-MR/r4i1p1f1/gn/
# Processing past for AWI-CM-1-1-MR r5i1p1f1...
# /project/cmip6/historical/Amon/ua/AWI-CM-1-1-MR/r5i1p1f1/gn/
# Processing future for AWI-CM-1-1-MR r1i1p1f1
# Processing past for BCC-CSM2-MR r1i1p1f1...
# /project/cmip6/historical/Amon/ua/BCC-CSM2-MR/r1i1p1f1/gn/
# Processing past for BCC-CSM2-MR r2i1p1f1...
# /project/cmip6/historical/Amon/ua/BCC-CSM2-MR/r2i1p1f1/gn/
# Processing past for BCC-CSM2-MR r3i1p1f1...
# /project/cmip6/historical/Amon/ua/BCC-CSM2-MR/r3i1p1f1/gn/
# Processing future for BCC-CSM2-MR r1i1p1f1
# Processing past for CAMS-CSM1-0 r1i1p1f1...
# /project/cmip6/historical/Amon/ua/CAMS-CSM1-0/r1i1p1f1/gn/
# Processing future for CAMS-CSM1-0 r1i1p1f1
# Processing future for CAMS-CSM1-0 r2i1p1f1
# Processing past for CanESM5 r1i1p1f1...
# /project/cmip6/historical/Amon/ua/CanESM5/r1i1p1f1/gn/
# Processing past for CanESM5 r2i1p1f1...
# /project/cmip6/historical/Amon/ua/CanESM5/r2i1p1f1/gn/
# Processing past for CanESM5 r3i1p1f1...
# /project/cmip6/historical/Amon/ua/CanESM5/r3i1p1f1/gn/
# Processing past for CanESM5 r4i1p1f1...
# /project/cmip6/historical/Amon/ua/CanESM5/r4i1p1f1/gn/
# Processing past for CanESM5 r5i1p1f1...
# /project/cmip6/historical/Amon/ua/CanESM5/r5i1p1f1/gn/
# Processing past for CanESM5 r6i1p1f1...
# /project/cmip6/historical/Amon/ua/CanESM5/r6i1p1f1/gn/
# Processing past for CanESM5 r7i1p1f1...
# /project/cmip6/historical/Amon/ua/CanESM5/r7i1p1f1/gn/
# Processing past for CanESM5 r8i1p1f1...
# /project/cmip6/historical/Amon/ua/CanESM5/r8i1p1f1/gn/
# Processing past for CanESM5 r9i1p1f1...
# /project/cmip6/historical/Amon/ua/CanESM5/r9i1p1f1/gn/
# Processing past for CanESM5 r10i1p1f1...
# /project/cmip6/historical/Amon/ua/CanESM5/r10i1p1f1/gn/
# Processing past for CanESM5 r11i1p1f1...
# /project/cmip6/historical/Amon/ua/CanESM5/r11i1p1f1/gn/
# Processing past for CanESM5 r12i1p1f1...
# /project/cmip6/historical/Amon/ua/CanESM5/r12i1p1f1/gn/
# Processing past for CanESM5 r13i1p1f1...
# /project/cmip6/historical/Amon/ua/CanESM5/r13i1p1f1/gn/
# Processing past for CanESM5 r14i1p1f1...
# /project/cmip6/historical/Amon/ua/CanESM5/r14i1p1f1/gn/
# Processing past for CanESM5 r15i1p1f1...
# /project/cmip6/historical/Amon/ua/CanESM5/r15i1p1f1/gn/
# Processing past for CanESM5 r16i1p1f1...
# /project/cmip6/historical/Amon/ua/CanESM5/r16i1p1f1/gn/
# Processing past for CanESM5 r17i1p1f1...
# /project/cmip6/historical/Amon/ua/CanESM5/r17i1p1f1/gn/
# Processing past for CanESM5 r18i1p1f1...
# /project/cmip6/historical/Amon/ua/CanESM5/r18i1p1f1/gn/
# Processing past for CanESM5 r19i1p1f1...
# /project/cmip6/historical/Amon/ua/CanESM5/r19i1p1f1/gn/
# Processing past for CanESM5 r20i1p1f1...
# /project/cmip6/historical/Amon/ua/CanESM5/r20i1p1f1/gn/
# Processing past for CanESM5 r21i1p1f1...
# /project/cmip6/historical/Amon/ua/CanESM5/r21i1p1f1/gn/
# Processing past for CanESM5 r22i1p1f1...
# /project/cmip6/historical/Amon/ua/CanESM5/r22i1p1f1/gn/
# Processing past for CanESM5 r23i1p1f1...
# /project/cmip6/historical/Amon/ua/CanESM5/r23i1p1f1/gn/
# Processing past for CanESM5 r24i1p1f1...
# /project/cmip6/historical/Amon/ua/CanESM5/r24i1p1f1/gn/
# Processing past for CanESM5 r25i1p1f1...
# /project/cmip6/historical/Amon/ua/CanESM5/r25i1p1f1/gn/
# Processing future for CanESM5 r1i1p1f1
# Processing future for CanESM5 r2i1p1f1
# Processing future for CanESM5 r3i1p1f1
# Processing future for CanESM5 r4i1p1f1
# Processing future for CanESM5 r5i1p1f1
# Processing future for CanESM5 r6i1p1f1
# Processing future for CanESM5 r7i1p1f1
# Processing future for CanESM5 r8i1p1f1
# Processing future for CanESM5 r9i1p1f1
# Processing future for CanESM5 r10i1p1f1
# Processing future for CanESM5 r11i1p1f1
# Processing future for CanESM5 r12i1p1f1
# Processing future for CanESM5 r13i1p1f1
# Processing future for CanESM5 r14i1p1f1
# Processing future for CanESM5 r15i1p1f1
# Processing future for CanESM5 r16i1p1f1
# Processing future for CanESM5 r17i1p1f1
# Processing future for CanESM5 r18i1p1f1
# Processing future for CanESM5 r19i1p1f1
# Processing future for CanESM5 r20i1p1f1
# Processing future for CanESM5 r21i1p1f1
# Processing future for CanESM5 r22i1p1f1
# Processing future for CanESM5 r23i1p1f1
# Processing future for CanESM5 r24i1p1f1
# Processing future for CanESM5 r25i1p1f1
# Processing past for CanESM5-CanOE r1i1p2f1...
# /project/cmip6/historical/Amon/ua/CanESM5-CanOE/r1i1p2f1/gn/
# Processing past for CanESM5-CanOE r2i1p2f1...
# /project/cmip6/historical/Amon/ua/CanESM5-CanOE/r2i1p2f1/gn/
# Processing past for CanESM5-CanOE r3i1p2f1...
# /project/cmip6/historical/Amon/ua/CanESM5-CanOE/r3i1p2f1/gn/
# Processing future for CanESM5-CanOE r1i1p2f1
# Processing future for CanESM5-CanOE r2i1p2f1
# Processing future for CanESM5-CanOE r3i1p2f1
# Processing past for CESM2 r1i1p1f1...
# /project/cmip6/historical/Amon/ua/CESM2/r1i1p1f1/gn/
# Processing past for CESM2 r2i1p1f1...
# /project/cmip6/historical/Amon/ua/CESM2/r2i1p1f1/gn/
# Processing past for CESM2 r3i1p1f1...
# /project/cmip6/historical/Amon/ua/CESM2/r3i1p1f1/gn/
# Processing past for CESM2 r4i1p1f1...
# /project/cmip6/historical/Amon/ua/CESM2/r4i1p1f1/gn/
# Processing past for CESM2 r5i1p1f1...
# /project/cmip6/historical/Amon/ua/CESM2/r5i1p1f1/gn/
# Processing past for CESM2 r6i1p1f1...
# /project/cmip6/historical/Amon/ua/CESM2/r6i1p1f1/gn/
# Processing past for CESM2 r7i1p1f1...
# /project/cmip6/historical/Amon/ua/CESM2/r7i1p1f1/gn/
# Processing past for CESM2 r8i1p1f1...
# /project/cmip6/historical/Amon/ua/CESM2/r8i1p1f1/gn/
# Processing past for CESM2 r9i1p1f1...
# /project/cmip6/historical/Amon/ua/CESM2/r9i1p1f1/gn/
# Processing past for CESM2 r11i1p1f1...
# /project/cmip6/historical/Amon/ua/CESM2/r11i1p1f1/gn/
# Processing future for CESM2 r1i1p1f1
# Processing future for CESM2 r2i1p1f1
# Processing past for CESM2-WACCM r1i1p1f1...
# /project/cmip6/historical/Amon/ua/CESM2-WACCM/r1i1p1f1/gn/
# Processing past for CESM2-WACCM r2i1p1f1...
# /project/cmip6/historical/Amon/ua/CESM2-WACCM/r2i1p1f1/gn/
# Processing past for CESM2-WACCM r3i1p1f1...
# /project/cmip6/historical/Amon/ua/CESM2-WACCM/r3i1p1f1/gn/
# Processing future for CESM2-WACCM r1i1p1f1
# Processing past for CIESM r1i1p1f1...
# /project/cmip6/historical/Amon/ua/CIESM/r1i1p1f1/gr/
# Processing past for CIESM r2i1p1f1...
# /project/cmip6/historical/Amon/ua/CIESM/r2i1p1f1/gr/
# Processing past for CIESM r3i1p1f1...
# /project/cmip6/historical/Amon/ua/CIESM/r3i1p1f1/gr/
# Processing future for CIESM r1i1p1f1
# Processing past for CMCC-CM2-SR5 r1i1p1f1...
# /project/cmip6/historical/Amon/ua/CMCC-CM2-SR5/r1i1p1f1/gn/
# Processing future for CMCC-CM2-SR5 r1i1p1f1
# Processing past for CNRM-CM6-1 r1i1p1f2...
# /project/cmip6/historical/Amon/ua/CNRM-CM6-1/r1i1p1f2/gr/
# Processing past for CNRM-CM6-1 r2i1p1f2...
# /project/cmip6/historical/Amon/ua/CNRM-CM6-1/r2i1p1f2/gr/
# Processing past for CNRM-CM6-1 r3i1p1f2...
# /project/cmip6/historical/Amon/ua/CNRM-CM6-1/r3i1p1f2/gr/
# Processing past for CNRM-CM6-1 r4i1p1f2...
# /project/cmip6/historical/Amon/ua/CNRM-CM6-1/r4i1p1f2/gr/
# Processing past for CNRM-CM6-1 r5i1p1f2...
# /project/cmip6/historical/Amon/ua/CNRM-CM6-1/r5i1p1f2/gr/
# Processing past for CNRM-CM6-1 r6i1p1f2...
# /project/cmip6/historical/Amon/ua/CNRM-CM6-1/r6i1p1f2/gr/
# Processing past for CNRM-CM6-1 r7i1p1f2...
# /project/cmip6/historical/Amon/ua/CNRM-CM6-1/r7i1p1f2/gr/
# Processing past for CNRM-CM6-1 r8i1p1f2...
# /project/cmip6/historical/Amon/ua/CNRM-CM6-1/r8i1p1f2/gr/
# Processing past for CNRM-CM6-1 r9i1p1f2...
# /project/cmip6/historical/Amon/ua/CNRM-CM6-1/r9i1p1f2/gr/
# Processing past for CNRM-CM6-1 r10i1p1f2...
# /project/cmip6/historical/Amon/ua/CNRM-CM6-1/r10i1p1f2/gr/
# Processing past for CNRM-CM6-1 r11i1p1f2...
# /project/cmip6/historical/Amon/ua/CNRM-CM6-1/r11i1p1f2/gr/
# Processing past for CNRM-CM6-1 r12i1p1f2...
# /project/cmip6/historical/Amon/ua/CNRM-CM6-1/r12i1p1f2/gr/
# Processing past for CNRM-CM6-1 r13i1p1f2...
# /project/cmip6/historical/Amon/ua/CNRM-CM6-1/r13i1p1f2/gr/
# Processing past for CNRM-CM6-1 r14i1p1f2...
# /project/cmip6/historical/Amon/ua/CNRM-CM6-1/r14i1p1f2/gr/
# Processing past for CNRM-CM6-1 r15i1p1f2...
# /project/cmip6/historical/Amon/ua/CNRM-CM6-1/r15i1p1f2/gr/
# Processing future for CNRM-CM6-1 r1i1p1f2
# Processing future for CNRM-CM6-1 r2i1p1f2
# Processing future for CNRM-CM6-1 r3i1p1f2
# Processing future for CNRM-CM6-1 r4i1p1f2
# Processing future for CNRM-CM6-1 r5i1p1f2
# Processing future for CNRM-CM6-1 r6i1p1f2
# Processing past for CNRM-CM6-1-HR r1i1p1f2...
# /project/cmip6/historical/Amon/ua/CNRM-CM6-1-HR/r1i1p1f2/gr/
# Processing future for CNRM-CM6-1-HR r1i1p1f2
# Processing past for CNRM-ESM2-1 r1i1p1f2...
# /project/cmip6/historical/Amon/ua/CNRM-ESM2-1/r1i1p1f2/gr/
# Processing past for CNRM-ESM2-1 r2i1p1f2...
# /project/cmip6/historical/Amon/ua/CNRM-ESM2-1/r2i1p1f2/gr/
# Processing past for CNRM-ESM2-1 r3i1p1f2...
# /project/cmip6/historical/Amon/ua/CNRM-ESM2-1/r3i1p1f2/gr/
# Processing past for CNRM-ESM2-1 r4i1p1f2...
# /project/cmip6/historical/Amon/ua/CNRM-ESM2-1/r4i1p1f2/gr/
# Processing past for CNRM-ESM2-1 r5i1p1f2...
# /project/cmip6/historical/Amon/ua/CNRM-ESM2-1/r5i1p1f2/gr/
# Processing future for CNRM-ESM2-1 r1i1p1f2
# Processing future for CNRM-ESM2-1 r2i1p1f2
# Processing future for CNRM-ESM2-1 r3i1p1f2
# Processing future for CNRM-ESM2-1 r4i1p1f2
# Processing future for CNRM-ESM2-1 r5i1p1f2
# Processing past for EC-Earth3 r1i1p1f1...
# /project/cmip6/historical/Amon/ua/EC-Earth3/r1i1p1f1/gr/
# Processing past for EC-Earth3 r4i1p1f1...
# /project/cmip6/historical/Amon/ua/EC-Earth3/r4i1p1f1/gr/
# Processing past for EC-Earth3 r6i1p1f1...
# /project/cmip6/historical/Amon/ua/EC-Earth3/r6i1p1f1/gr/
# Processing past for EC-Earth3 r9i1p1f1...
# /project/cmip6/historical/Amon/ua/EC-Earth3/r9i1p1f1/gr/
# Processing past for EC-Earth3 r11i1p1f1...
# /project/cmip6/historical/Amon/ua/EC-Earth3/r11i1p1f1/gr/
# Processing past for EC-Earth3 r13i1p1f1...
# /project/cmip6/historical/Amon/ua/EC-Earth3/r13i1p1f1/gr/
# Processing past for EC-Earth3 r15i1p1f1...
# /project/cmip6/historical/Amon/ua/EC-Earth3/r15i1p1f1/gr/
# Processing past for EC-Earth3 r21i1p1f1...
# /project/cmip6/historical/Amon/ua/EC-Earth3/r21i1p1f1/gr/
# Processing past for EC-Earth3 r22i1p1f1...
# /project/cmip6/historical/Amon/ua/EC-Earth3/r22i1p1f1/gr/
# Processing past for EC-Earth3 r24i1p1f1...
# /project/cmip6/historical/Amon/ua/EC-Earth3/r24i1p1f1/gr/
# Processing future for EC-Earth3 r1i1p1f1
# Processing future for EC-Earth3 r4i1p1f1
# Processing future for EC-Earth3 r6i1p1f1
# Processing future for EC-Earth3 r9i1p1f1
# Processing future for EC-Earth3 r11i1p1f1
# Processing future for EC-Earth3 r13i1p1f1
# Processing future for EC-Earth3 r15i1p1f1
# Processing past for EC-Earth3-Veg r1i1p1f1...
# /project/cmip6/historical/Amon/ua/EC-Earth3-Veg/r1i1p1f1/gr/
# Processing past for EC-Earth3-Veg r2i1p1f1...
# /project/cmip6/historical/Amon/ua/EC-Earth3-Veg/r2i1p1f1/gr/
# Processing past for EC-Earth3-Veg r3i1p1f1...
# /project/cmip6/historical/Amon/ua/EC-Earth3-Veg/r3i1p1f1/gr/
# Processing past for EC-Earth3-Veg r4i1p1f1...
# /project/cmip6/historical/Amon/ua/EC-Earth3-Veg/r4i1p1f1/gr/
# Processing future for EC-Earth3-Veg r1i1p1f1
# Processing future for EC-Earth3-Veg r2i1p1f1
# Processing future for EC-Earth3-Veg r4i1p1f1
# Processing past for FGOALS-f3-L r1i1p1f1...
# /project/cmip6/historical/Amon/ua/FGOALS-f3-L/r1i1p1f1/gr/
# Processing past for FGOALS-f3-L r2i1p1f1...
# /project/cmip6/historical/Amon/ua/FGOALS-f3-L/r2i1p1f1/gr/
# Processing past for FGOALS-f3-L r3i1p1f1...
# /project/cmip6/historical/Amon/ua/FGOALS-f3-L/r3i1p1f1/gr/
# Processing future for FGOALS-f3-L r1i1p1f1
# Processing past for FGOALS-g3 r1i1p1f1...
# /project/cmip6/historical/Amon/ua/FGOALS-g3/r1i1p1f1/gn/
# Processing past for FGOALS-g3 r2i1p1f1...
# /project/cmip6/historical/Amon/ua/FGOALS-g3/r2i1p1f1/gn/
# Processing past for FGOALS-g3 r3i1p1f1...
# /project/cmip6/historical/Amon/ua/FGOALS-g3/r3i1p1f1/gn/
# Processing future for FGOALS-g3 r1i1p1f1
# Processing past for FIO-ESM-2-0 r1i1p1f1...
# /project/cmip6/historical/Amon/ua/FIO-ESM-2-0/r1i1p1f1/gn/
# Processing past for FIO-ESM-2-0 r2i1p1f1...
# /project/cmip6/historical/Amon/ua/FIO-ESM-2-0/r2i1p1f1/gn/
# Processing past for FIO-ESM-2-0 r3i1p1f1...
# /project/cmip6/historical/Amon/ua/FIO-ESM-2-0/r3i1p1f1/gn/
# Processing future for FIO-ESM-2-0 r1i1p1f1
# Processing future for FIO-ESM-2-0 r2i1p1f1
# Processing future for FIO-ESM-2-0 r3i1p1f1
# Processing past for GFDL-CM4 r1i1p1f1...
# /project/cmip6/historical/Amon/ua/GFDL-CM4/r1i1p1f1/gr1/
# Processing future for GFDL-CM4 r1i1p1f1
# Processing past for GFDL-ESM4 r1i1p1f1...
# /project/cmip6/historical/Amon/ua/GFDL-ESM4/r1i1p1f1/gr1/
# Processing future for GFDL-ESM4 r1i1p1f1
# Processing past for GISS-E2-1-G r1i1p1f1...
# /project/cmip6/historical/Amon/ua/GISS-E2-1-G/r1i1p1f1/gn/
# Processing past for GISS-E2-1-G r2i1p1f1...
# /project/cmip6/historical/Amon/ua/GISS-E2-1-G/r2i1p1f1/gn/
# Processing past for GISS-E2-1-G r3i1p1f1...
# /project/cmip6/historical/Amon/ua/GISS-E2-1-G/r3i1p1f1/gn/
# Processing past for GISS-E2-1-G r4i1p1f1...
# /project/cmip6/historical/Amon/ua/GISS-E2-1-G/r4i1p1f1/gn/
# Processing past for GISS-E2-1-G r5i1p1f1...
# /project/cmip6/historical/Amon/ua/GISS-E2-1-G/r5i1p1f1/gn/
# Processing past for GISS-E2-1-G r6i1p1f1...
# /project/cmip6/historical/Amon/ua/GISS-E2-1-G/r6i1p1f1/gn/
# Processing past for GISS-E2-1-G r7i1p1f1...
# /project/cmip6/historical/Amon/ua/GISS-E2-1-G/r7i1p1f1/gn/
# Processing past for GISS-E2-1-G r8i1p1f1...
# /project/cmip6/historical/Amon/ua/GISS-E2-1-G/r8i1p1f1/gn/
# Processing past for GISS-E2-1-G r9i1p1f1...
# /project/cmip6/historical/Amon/ua/GISS-E2-1-G/r9i1p1f1/gn/
# Processing past for GISS-E2-1-G r10i1p1f1...
# /project/cmip6/historical/Amon/ua/GISS-E2-1-G/r10i1p1f1/gn/
# Processing future for GISS-E2-1-G r1i1p1f2
# Processing past for HadGEM3-GC31-LL r1i1p1f3...
# /project/cmip6/historical/Amon/ua/HadGEM3-GC31-LL/r1i1p1f3/gn/
# Processing past for HadGEM3-GC31-LL r2i1p1f3...
# /project/cmip6/historical/Amon/ua/HadGEM3-GC31-LL/r2i1p1f3/gn/
# Processing past for HadGEM3-GC31-LL r3i1p1f3...
# /project/cmip6/historical/Amon/ua/HadGEM3-GC31-LL/r3i1p1f3/gn/
# Processing past for HadGEM3-GC31-LL r4i1p1f3...
# /project/cmip6/historical/Amon/ua/HadGEM3-GC31-LL/r4i1p1f3/gn/
# Processing future for HadGEM3-GC31-LL r1i1p1f3
# Processing future for HadGEM3-GC31-LL r2i1p1f3
# Processing future for HadGEM3-GC31-LL r3i1p1f3
# Processing past for HadGEM3-GC31-MM r1i1p1f3...
# /project/cmip6/historical/Amon/ua/HadGEM3-GC31-MM/r1i1p1f3/gn/
# Processing past for HadGEM3-GC31-MM r2i1p1f3...
# /project/cmip6/historical/Amon/ua/HadGEM3-GC31-MM/r2i1p1f3/gn/
# Processing past for HadGEM3-GC31-MM r3i1p1f3...
# /project/cmip6/historical/Amon/ua/HadGEM3-GC31-MM/r3i1p1f3/gn/
# Processing past for HadGEM3-GC31-MM r4i1p1f3...
# /project/cmip6/historical/Amon/ua/HadGEM3-GC31-MM/r4i1p1f3/gn/
# Processing future for HadGEM3-GC31-MM r1i1p1f3
# Processing future for HadGEM3-GC31-MM r2i1p1f3
# Processing future for HadGEM3-GC31-MM r3i1p1f3
# Processing past for INM-CM4-8 r1i1p1f1...
# /project/cmip6/historical/Amon/ua/INM-CM4-8/r1i1p1f1/gr1/
# Processing future for INM-CM4-8 r1i1p1f1
# Processing past for INM-CM5-0 r1i1p1f1...
# /project/cmip6/historical/Amon/ua/INM-CM5-0/r1i1p1f1/gr1/
# Processing past for INM-CM5-0 r2i1p1f1...
# /project/cmip6/historical/Amon/ua/INM-CM5-0/r2i1p1f1/gr1/
# Processing past for INM-CM5-0 r5i1p1f1...
# /project/cmip6/historical/Amon/ua/INM-CM5-0/r5i1p1f1/gr1/
# Processing past for INM-CM5-0 r6i1p1f1...
# /project/cmip6/historical/Amon/ua/INM-CM5-0/r6i1p1f1/gr1/
# Processing past for INM-CM5-0 r7i1p1f1...
# /project/cmip6/historical/Amon/ua/INM-CM5-0/r7i1p1f1/gr1/
# Processing past for INM-CM5-0 r8i1p1f1...
# /project/cmip6/historical/Amon/ua/INM-CM5-0/r8i1p1f1/gr1/
# Processing past for INM-CM5-0 r9i1p1f1...
# /project/cmip6/historical/Amon/ua/INM-CM5-0/r9i1p1f1/gr1/
# Processing past for INM-CM5-0 r10i1p1f1...
# /project/cmip6/historical/Amon/ua/INM-CM5-0/r10i1p1f1/gr1/
# Processing future for INM-CM5-0 r1i1p1f1
# Processing past for IPSL-CM6A-LR r1i1p1f1...
# /project/cmip6/historical/Amon/ua/IPSL-CM6A-LR/r1i1p1f1/gr/
# Processing past for IPSL-CM6A-LR r2i1p1f1...
# /project/cmip6/historical/Amon/ua/IPSL-CM6A-LR/r2i1p1f1/gr/
# Processing past for IPSL-CM6A-LR r3i1p1f1...
# /project/cmip6/historical/Amon/ua/IPSL-CM6A-LR/r3i1p1f1/gr/
# Processing past for IPSL-CM6A-LR r4i1p1f1...
# /project/cmip6/historical/Amon/ua/IPSL-CM6A-LR/r4i1p1f1/gr/
# Processing past for IPSL-CM6A-LR r5i1p1f1...
# /project/cmip6/historical/Amon/ua/IPSL-CM6A-LR/r5i1p1f1/gr/
# Processing past for IPSL-CM6A-LR r6i1p1f1...
# /project/cmip6/historical/Amon/ua/IPSL-CM6A-LR/r6i1p1f1/gr/
# Processing past for IPSL-CM6A-LR r7i1p1f1...
# /project/cmip6/historical/Amon/ua/IPSL-CM6A-LR/r7i1p1f1/gr/
# Processing past for IPSL-CM6A-LR r8i1p1f1...
# /project/cmip6/historical/Amon/ua/IPSL-CM6A-LR/r8i1p1f1/gr/
# Processing past for IPSL-CM6A-LR r9i1p1f1...
# /project/cmip6/historical/Amon/ua/IPSL-CM6A-LR/r9i1p1f1/gr/
# Processing past for IPSL-CM6A-LR r10i1p1f1...
# /project/cmip6/historical/Amon/ua/IPSL-CM6A-LR/r10i1p1f1/gr/
# Processing past for IPSL-CM6A-LR r11i1p1f1...
# /project/cmip6/historical/Amon/ua/IPSL-CM6A-LR/r11i1p1f1/gr/
# Processing past for IPSL-CM6A-LR r12i1p1f1...
# /project/cmip6/historical/Amon/ua/IPSL-CM6A-LR/r12i1p1f1/gr/
# Processing past for IPSL-CM6A-LR r13i1p1f1...
# /project/cmip6/historical/Amon/ua/IPSL-CM6A-LR/r13i1p1f1/gr/
# Processing past for IPSL-CM6A-LR r14i1p1f1...
# /project/cmip6/historical/Amon/ua/IPSL-CM6A-LR/r14i1p1f1/gr/
# Processing past for IPSL-CM6A-LR r15i1p1f1...
# /project/cmip6/historical/Amon/ua/IPSL-CM6A-LR/r15i1p1f1/gr/
# Processing past for IPSL-CM6A-LR r16i1p1f1...
# /project/cmip6/historical/Amon/ua/IPSL-CM6A-LR/r16i1p1f1/gr/
# Processing past for IPSL-CM6A-LR r17i1p1f1...
# /project/cmip6/historical/Amon/ua/IPSL-CM6A-LR/r17i1p1f1/gr/
# Processing past for IPSL-CM6A-LR r18i1p1f1...
# /project/cmip6/historical/Amon/ua/IPSL-CM6A-LR/r18i1p1f1/gr/
# Processing past for IPSL-CM6A-LR r19i1p1f1...
# /project/cmip6/historical/Amon/ua/IPSL-CM6A-LR/r19i1p1f1/gr/
# Processing past for IPSL-CM6A-LR r20i1p1f1...
# /project/cmip6/historical/Amon/ua/IPSL-CM6A-LR/r20i1p1f1/gr/
# Processing past for IPSL-CM6A-LR r21i1p1f1...
# /project/cmip6/historical/Amon/ua/IPSL-CM6A-LR/r21i1p1f1/gr/
# Processing past for IPSL-CM6A-LR r22i1p1f1...
# /project/cmip6/historical/Amon/ua/IPSL-CM6A-LR/r22i1p1f1/gr/
# Processing past for IPSL-CM6A-LR r23i1p1f1...
# /project/cmip6/historical/Amon/ua/IPSL-CM6A-LR/r23i1p1f1/gr/
# Processing past for IPSL-CM6A-LR r24i1p1f1...
# /project/cmip6/historical/Amon/ua/IPSL-CM6A-LR/r24i1p1f1/gr/
# Processing past for IPSL-CM6A-LR r25i1p1f1...
# /project/cmip6/historical/Amon/ua/IPSL-CM6A-LR/r25i1p1f1/gr/
# Processing past for IPSL-CM6A-LR r26i1p1f1...
# /project/cmip6/historical/Amon/ua/IPSL-CM6A-LR/r26i1p1f1/gr/
# Processing past for IPSL-CM6A-LR r27i1p1f1...
# /project/cmip6/historical/Amon/ua/IPSL-CM6A-LR/r27i1p1f1/gr/
# Processing past for IPSL-CM6A-LR r28i1p1f1...
# /project/cmip6/historical/Amon/ua/IPSL-CM6A-LR/r28i1p1f1/gr/
# Processing past for IPSL-CM6A-LR r29i1p1f1...
# /project/cmip6/historical/Amon/ua/IPSL-CM6A-LR/r29i1p1f1/gr/
# Processing past for IPSL-CM6A-LR r30i1p1f1...
# /project/cmip6/historical/Amon/ua/IPSL-CM6A-LR/r30i1p1f1/gr/
# Processing past for IPSL-CM6A-LR r31i1p1f1...
# /project/cmip6/historical/Amon/ua/IPSL-CM6A-LR/r31i1p1f1/gr/
# Processing past for IPSL-CM6A-LR r32i1p1f1...
# /project/cmip6/historical/Amon/ua/IPSL-CM6A-LR/r32i1p1f1/gr/
# Processing future for IPSL-CM6A-LR r1i1p1f1
# Processing past for KACE-1-0-G r1i1p1f1...
# /project/cmip6/historical/Amon/ua/KACE-1-0-G/r1i1p1f1/gr/
# Processing past for KACE-1-0-G r2i1p1f1...
# /project/cmip6/historical/Amon/ua/KACE-1-0-G/r2i1p1f1/gr/
# Processing past for KACE-1-0-G r3i1p1f1...
# /project/cmip6/historical/Amon/ua/KACE-1-0-G/r3i1p1f1/gr/
# Processing future for KACE-1-0-G r1i1p1f1
# Processing past for MCM-UA-1-0 r1i1p1f1...
# /project/cmip6/historical/Amon/ua/MCM-UA-1-0/r1i1p1f1/gn/
# Processing future for MCM-UA-1-0 r1i1p1f2
# Processing past for MIROC6 r1i1p1f1...
# /project/cmip6/historical/Amon/ua/MIROC6/r1i1p1f1/gn/
# Processing past for MIROC6 r2i1p1f1...
# /project/cmip6/historical/Amon/ua/MIROC6/r2i1p1f1/gn/
# Processing past for MIROC6 r3i1p1f1...
# /project/cmip6/historical/Amon/ua/MIROC6/r3i1p1f1/gn/
# Processing past for MIROC6 r4i1p1f1...
# /project/cmip6/historical/Amon/ua/MIROC6/r4i1p1f1/gn/
# Processing past for MIROC6 r5i1p1f1...
# /project/cmip6/historical/Amon/ua/MIROC6/r5i1p1f1/gn/
# Processing past for MIROC6 r6i1p1f1...
# /project/cmip6/historical/Amon/ua/MIROC6/r6i1p1f1/gn/
# Processing past for MIROC6 r7i1p1f1...
# /project/cmip6/historical/Amon/ua/MIROC6/r7i1p1f1/gn/
# Processing past for MIROC6 r8i1p1f1...
# /project/cmip6/historical/Amon/ua/MIROC6/r8i1p1f1/gn/
# Processing past for MIROC6 r9i1p1f1...
# /project/cmip6/historical/Amon/ua/MIROC6/r9i1p1f1/gn/
# Processing past for MIROC6 r10i1p1f1...
# /project/cmip6/historical/Amon/ua/MIROC6/r10i1p1f1/gn/
# Processing future for MIROC6 r1i1p1f1
# Processing future for MIROC6 r2i1p1f1
# Processing future for MIROC6 r3i1p1f1
# Processing past for MIROC-ES2L r1i1p1f2...
# /project/cmip6/historical/Amon/ua/MIROC-ES2L/r1i1p1f2/gn/
# Processing past for MIROC-ES2L r2i1p1f2...
# /project/cmip6/historical/Amon/ua/MIROC-ES2L/r2i1p1f2/gn/
# Processing past for MIROC-ES2L r3i1p1f2...
# /project/cmip6/historical/Amon/ua/MIROC-ES2L/r3i1p1f2/gn/
# Processing future for MIROC-ES2L r1i1p1f2
# Processing past for MPI-ESM1-2-HR r1i1p1f1...
# /project/cmip6/historical/Amon/ua/MPI-ESM1-2-HR/r1i1p1f1/gn/
# Processing past for MPI-ESM1-2-HR r2i1p1f1...
# /project/cmip6/historical/Amon/ua/MPI-ESM1-2-HR/r2i1p1f1/gn/
# Processing past for MPI-ESM1-2-HR r3i1p1f1...
# /project/cmip6/historical/Amon/ua/MPI-ESM1-2-HR/r3i1p1f1/gn/
# Processing past for MPI-ESM1-2-HR r4i1p1f1...
# /project/cmip6/historical/Amon/ua/MPI-ESM1-2-HR/r4i1p1f1/gn/
# Processing past for MPI-ESM1-2-HR r5i1p1f1...
# /project/cmip6/historical/Amon/ua/MPI-ESM1-2-HR/r5i1p1f1/gn/
# Processing past for MPI-ESM1-2-HR r6i1p1f1...
# /project/cmip6/historical/Amon/ua/MPI-ESM1-2-HR/r6i1p1f1/gn/
# Processing past for MPI-ESM1-2-HR r7i1p1f1...
# /project/cmip6/historical/Amon/ua/MPI-ESM1-2-HR/r7i1p1f1/gn/
# Processing past for MPI-ESM1-2-HR r8i1p1f1...
# /project/cmip6/historical/Amon/ua/MPI-ESM1-2-HR/r8i1p1f1/gn/
# Processing past for MPI-ESM1-2-HR r9i1p1f1...
# /project/cmip6/historical/Amon/ua/MPI-ESM1-2-HR/r9i1p1f1/gn/
# Processing past for MPI-ESM1-2-HR r10i1p1f1...
# /project/cmip6/historical/Amon/ua/MPI-ESM1-2-HR/r10i1p1f1/gn/
# Processing future for MPI-ESM1-2-HR r1i1p1f1
# Processing past for MPI-ESM1-2-LR r1i1p1f1...
# /project/cmip6/historical/Amon/ua/MPI-ESM1-2-LR/r1i1p1f1/gn/
# Processing past for MPI-ESM1-2-LR r2i1p1f1...
# /project/cmip6/historical/Amon/ua/MPI-ESM1-2-LR/r2i1p1f1/gn/
# Processing past for MPI-ESM1-2-LR r3i1p1f1...
# /project/cmip6/historical/Amon/ua/MPI-ESM1-2-LR/r3i1p1f1/gn/
# Processing past for MPI-ESM1-2-LR r4i1p1f1...
# /project/cmip6/historical/Amon/ua/MPI-ESM1-2-LR/r4i1p1f1/gn/
# Processing past for MPI-ESM1-2-LR r5i1p1f1...
# /project/cmip6/historical/Amon/ua/MPI-ESM1-2-LR/r5i1p1f1/gn/
# Processing past for MPI-ESM1-2-LR r6i1p1f1...
# /project/cmip6/historical/Amon/ua/MPI-ESM1-2-LR/r6i1p1f1/gn/
# Processing past for MPI-ESM1-2-LR r7i1p1f1...
# /project/cmip6/historical/Amon/ua/MPI-ESM1-2-LR/r7i1p1f1/gn/
# Processing past for MPI-ESM1-2-LR r8i1p1f1...
# /project/cmip6/historical/Amon/ua/MPI-ESM1-2-LR/r8i1p1f1/gn/
# Processing past for MPI-ESM1-2-LR r9i1p1f1...
# /project/cmip6/historical/Amon/ua/MPI-ESM1-2-LR/r9i1p1f1/gn/
# Processing past for MPI-ESM1-2-LR r10i1p1f1...
# /project/cmip6/historical/Amon/ua/MPI-ESM1-2-LR/r10i1p1f1/gn/
# Processing future for MPI-ESM1-2-LR r1i1p1f1
# Processing past for MRI-ESM2-0 r1i1p1f1...
# /project/cmip6/historical/Amon/ua/MRI-ESM2-0/r1i1p1f1/gn/
# Processing past for MRI-ESM2-0 r2i1p1f1...
# /project/cmip6/historical/Amon/ua/MRI-ESM2-0/r2i1p1f1/gn/
# Processing past for MRI-ESM2-0 r3i1p1f1...
# /project/cmip6/historical/Amon/ua/MRI-ESM2-0/r3i1p1f1/gn/
# Processing past for MRI-ESM2-0 r4i1p1f1...
# /project/cmip6/historical/Amon/ua/MRI-ESM2-0/r4i1p1f1/gn/
# Processing past for MRI-ESM2-0 r5i1p1f1...
# /project/cmip6/historical/Amon/ua/MRI-ESM2-0/r5i1p1f1/gn/
# Processing future for MRI-ESM2-0 r1i1p1f1
# Processing past for NESM3 r1i1p1f1...
# /project/cmip6/historical/Amon/ua/NESM3/r1i1p1f1/gn/
# Processing past for NESM3 r2i1p1f1...
# /project/cmip6/historical/Amon/ua/NESM3/r2i1p1f1/gn/
# Processing past for NESM3 r3i1p1f1...
# /project/cmip6/historical/Amon/ua/NESM3/r3i1p1f1/gn/
# Processing past for NESM3 r4i1p1f1...
# /project/cmip6/historical/Amon/ua/NESM3/r4i1p1f1/gn/
# Processing past for NESM3 r5i1p1f1...
# /project/cmip6/historical/Amon/ua/NESM3/r5i1p1f1/gn/
# Processing future for NESM3 r1i1p1f1
# Processing future for NESM3 r2i1p1f1
# Processing past for NorESM2-LM r1i1p1f1...
# /project/cmip6/historical/Amon/ua/NorESM2-LM/r1i1p1f1/gn/
# Processing past for NorESM2-LM r2i1p1f1...
# /project/cmip6/historical/Amon/ua/NorESM2-LM/r2i1p1f1/gn/
# Processing past for NorESM2-LM r3i1p1f1...
# /project/cmip6/historical/Amon/ua/NorESM2-LM/r3i1p1f1/gn/
# Processing future for NorESM2-LM r1i1p1f1
# Processing past for NorESM2-MM r1i1p1f1...
# /project/cmip6/historical/Amon/ua/NorESM2-MM/r1i1p1f1/gn/
# Processing future for NorESM2-MM r1i1p1f1
# Processing past for UKESM1-0-LL r1i1p1f2...
# /project/cmip6/historical/Amon/ua/UKESM1-0-LL/r1i1p1f2/gn/
# Processing past for UKESM1-0-LL r2i1p1f2...
# /project/cmip6/historical/Amon/ua/UKESM1-0-LL/r2i1p1f2/gn/
# Processing past for UKESM1-0-LL r3i1p1f2...
# /project/cmip6/historical/Amon/ua/UKESM1-0-LL/r3i1p1f2/gn/
# Processing past for UKESM1-0-LL r4i1p1f2...
# /project/cmip6/historical/Amon/ua/UKESM1-0-LL/r4i1p1f2/gn/
# Processing future for UKESM1-0-LL r1i1p1f2
# Processing future for UKESM1-0-LL r2i1p1f2
# Processing future for UKESM1-0-LL r3i1p1f2
# Processing future for UKESM1-0-LL r4i1p1f2
# Processing future for UKESM1-0-LL r8i1p1f2

# %% [markdown]
# Calculate indices and output to netcdf

# %%
# V_SW index
u100_past_em = avg.cosweightlat(upast_em,20,40)
u100_fut_em = avg.cosweightlat(ufut_em,20,40)
u100 = u100_fut_em - u100_past_em
u100.to_netcdf(pathout+"u100_CMIP5.nc")
