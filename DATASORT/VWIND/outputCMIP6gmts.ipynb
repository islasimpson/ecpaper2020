# %% [markdown]
# Calculate the global mean T2m for 1979-2014 and 2070-2099 of the CMIP6 models.  Outputs both the global mean T2m of the ensemble mean and the first ensemble member.  Using the historical simulations for the past and the SSP5-8.5 simulations for the future  This code works on a CMIP archive that is internal to the Climate and Global Dynamics Laboratory, NCAR.  I you want to run this on your own archive, you'd need to modify histpath and rcp85path and make sure the directory structure is set up in the right way.

# %%
import importlib
import pandas as pd
import xarray as xr
import numpy as np
from numpy import nan
import sys
import warnings
import math
from glob import glob

from ecpaper_utils import readdata_utils as read
from ecpaper_utils import averaging_utils as avg
from ecpaper_utils import calendar_utils as cal

importlib.reload(read)
importlib.reload(avg)

warnings.filterwarnings('ignore')

# %% [markdown]
# Set path for CMIP6 models (historical and SSP5-8.5) and output directory

# %%
histpath="/project/cmip6/historical/Amon/"
ssp585path="/project/cmip6/ssp585/Amon/"
pathout="/project/cas/islas/python/ecpaper2020/DATASORT/VWIND/DATA/"

# %% [markdown]
# Information on the models being used is provided in cmip6csvinfo.csv.  This contains information on the models, number of member and whether there's any special order for the member numbers i.e., if they don't simply go from 1 to N.  Read in this info and set up the dates for each period.

# %%
cmip6models=pd.read_csv('../cmip6csvinfo.csv')

ybegp = 1979 ; monbegp = 1 ; yendp = 2014 ; monendp = 12 # dates for Past period
ybegf = 2070 ; monbegf = 1 ; yendf = 2099 ; monendf = 12 # dates for Future period

# total number of months (used for checking)
nmonthsp = (yendp-ybegp-1)*12 + (12-monbegp+1) + monendp
nmonthsf = (yendf-ybegf-1)*12 + (12-monbegf+1) + monendf

# set up date names
datebegp=str(ybegp)+"-"+str(monbegp).zfill(2)
dateendp=str(yendp)+"-"+str(monendp).zfill(2)
datebegf=str(ybegf)+"-"+str(monbegf).zfill(2)
dateendf=str(yendf)+"-"+str(monendf).zfill(2)

# %% [markdown]
# This is the main part of the script.  It loops over models and ensemble members and calculates the global mean T2m for JJA for both the ensemble mean and the first member.  These are then output to netcdf

# %%
models=cmip6models['Model']
nmodels=models.size

tas1memp = xr.DataArray(np.zeros(nmodels), coords=[models], dims="Model", name="tas1memp")
tas1memf = xr.DataArray(np.zeros(nmodels), coords=[models], dims="Model", name="tas1memf")
tasemp = xr.DataArray(np.zeros(nmodels), coords=[models], dims="Model", name="tasemp")
tasemf = xr.DataArray(np.zeros(nmodels), coords=[models], dims="Model", name="tasemf")

# loop over models
for index, modname in models.iteritems():
    
    # ----- sort out the PAST period ---
    nmems = cmip6models.loc[index, "Nmempast"]
    ftype = cmip6models.loc[index, "ftypep"]
    ptype = cmip6models.loc[index, "ptype"]
    
    for imem in range(1,nmems+1,1):
        if (math.isnan(ptype)):
            memstr="r"+str(imem)+"i1p1f"+str(int(ftype))
        else:
            memstr="r"+str(imem)+"i1p"+str(int(ptype))+"f"+str(int(ftype))

        print("Outputting past for "+modname+" "+memstr)
            
            
        # check if a special order is needed
        changeorder = cmip6models.loc[index, "specialorderpast"]
        if (type(changeorder) == str):
            changeordernp = np.array(changeorder.split(","))
            if (type(changeorder) == str):
                changeordernp = np.array(changeorder.split(","))
                if (math.isnan(ptype)):
                    memstr = "r"+str(changeordernp[imem-1])+"i1p1f"+str(int(ftype))
                else:
                    memstr = "r"+str(changeordernp[imem-1])+"i1p"+str(int(ptype))+"f"+str(int(ftype))
            
        histdir = glob(histpath+"tas/"+modname+"/"+memstr+"/*/")
        histdir = histdir[0]


        # read in zonal tas, concatenate historical to 2005 and rcp8.5 to 2014
        tas=read.read_sfc(histdir+"*.nc", datebegp, dateendp)
        
        # check the array length.  
        if (tas.time.size != nmonthsp):
            print("something's wrong, nmonthsp="+str(nmonthsp)+" but tas has size "+str(tas.time.size))
            
        # calculate the JJA mean
        tasdjf = cal.season_mean(tas,"tas", season="DJF")
        tasgm = avg.cosweightlonlat(tasdjf,0,360,-90,90)

        # save the first member
        if (imem == 1):
            tas1memp[index]=tasgm

        # calculate the ensemble mean
        tasemp[index]=tasemp[index]+tasgm/float(nmems)
        
    # ---sort out the future period
    nmems = cmip6models.loc[index, "Nmemfuture"]
    ftype = cmip6models.loc[index, "ftypef"]
    
    for imem in range(1,nmems+1,1):
        
        if (math.isnan(ptype)):
            memstr="r"+str(imem)+"i1p1f"+str(int(ftype))
        else:
            memstr="r"+str(imem)+"i1p"+str(int(ptype))+"f"+str(int(ftype))
        
        # check if a special order is needed
        changeorder = cmip6models.loc[index, "specialorderfuture"]
        if (type(changeorder) == str):
            changeordernp = np.array(changeorder.split(","))
            if (type(changeorder) == str):
                changeordernp = np.array(changeorder.split(","))
                if (math.isnan(ptype)):
                    memstr = "r"+str(changeordernp[imem-1])+"i1p1f"+str(int(ftype))
                else:
                    memstr = "r"+str(changeordernp[imem-1])+"i1p"+str(int(ptype))+"f"+str(int(ftype))

        print("Outputting future for "+modname+" "+memstr)
                    
        ssp585dir = glob(ssp585path+"/tas/"+modname+"/"+memstr+"/*/")
        ssp585dir = ssp585dir[0]
        
        tas = read.read_sfc(ssp585dir+"*.nc",datebegf, dateendf)
        
        if (tas.time.size != nmonthsf):
            print("something's wrong, nmonthf="+str(nmonthsf)+" but tas has size "+str(tas.time.size))
            
        tasdjf = cal.season_mean(tas,"tas", season="DJF")
        tasgm = avg.cosweightlonlat(tasdjf, 0, 360, -90, 90)
        
        # save the first member
        if (imem == 1):
            tas1memf[index]=tasgm
            
        # calculate the ensemble mean
        tasemf[index]=tasemf[index]+tasgm/float(nmems)
# Out:
# Outputting past for ACCESS-CM2 r1i1p1f1
# Outputting past for ACCESS-CM2 r2i1p1f1
# Outputting future for ACCESS-CM2 r1i1p1f1
# Outputting past for ACCESS-ESM1-5 r1i1p1f1
# Outputting past for ACCESS-ESM1-5 r2i1p1f1
# Outputting past for ACCESS-ESM1-5 r3i1p1f1
# Outputting future for ACCESS-ESM1-5 r1i1p1f1
# Outputting future for ACCESS-ESM1-5 r2i1p1f1
# Outputting future for ACCESS-ESM1-5 r3i1p1f1
# Outputting past for AWI-CM-1-1-MR r1i1p1f1
# Outputting past for AWI-CM-1-1-MR r2i1p1f1
# Outputting past for AWI-CM-1-1-MR r3i1p1f1
# Outputting past for AWI-CM-1-1-MR r4i1p1f1
# Outputting past for AWI-CM-1-1-MR r5i1p1f1
# Outputting future for AWI-CM-1-1-MR r1i1p1f1
# Outputting past for BCC-CSM2-MR r1i1p1f1
# Outputting past for BCC-CSM2-MR r2i1p1f1
# Outputting past for BCC-CSM2-MR r3i1p1f1
# Outputting future for BCC-CSM2-MR r1i1p1f1
# Outputting past for CAMS-CSM1-0 r1i1p1f1
# Outputting future for CAMS-CSM1-0 r1i1p1f1
# Outputting future for CAMS-CSM1-0 r2i1p1f1
# Outputting past for CanESM5 r1i1p1f1
# Outputting past for CanESM5 r2i1p1f1
# Outputting past for CanESM5 r3i1p1f1
# Outputting past for CanESM5 r4i1p1f1
# Outputting past for CanESM5 r5i1p1f1
# Outputting past for CanESM5 r6i1p1f1
# Outputting past for CanESM5 r7i1p1f1
# Outputting past for CanESM5 r8i1p1f1
# Outputting past for CanESM5 r9i1p1f1
# Outputting past for CanESM5 r10i1p1f1
# Outputting past for CanESM5 r11i1p1f1
# Outputting past for CanESM5 r12i1p1f1
# Outputting past for CanESM5 r13i1p1f1
# Outputting past for CanESM5 r14i1p1f1
# Outputting past for CanESM5 r15i1p1f1
# Outputting past for CanESM5 r16i1p1f1
# Outputting past for CanESM5 r17i1p1f1
# Outputting past for CanESM5 r18i1p1f1
# Outputting past for CanESM5 r19i1p1f1
# Outputting past for CanESM5 r20i1p1f1
# Outputting past for CanESM5 r21i1p1f1
# Outputting past for CanESM5 r22i1p1f1
# Outputting past for CanESM5 r23i1p1f1
# Outputting past for CanESM5 r24i1p1f1
# Outputting past for CanESM5 r25i1p1f1
# Outputting future for CanESM5 r1i1p1f1
# Outputting future for CanESM5 r2i1p1f1
# Outputting future for CanESM5 r3i1p1f1
# Outputting future for CanESM5 r4i1p1f1
# Outputting future for CanESM5 r5i1p1f1
# Outputting future for CanESM5 r6i1p1f1
# Outputting future for CanESM5 r7i1p1f1
# Outputting future for CanESM5 r8i1p1f1
# Outputting future for CanESM5 r9i1p1f1
# Outputting future for CanESM5 r10i1p1f1
# Outputting future for CanESM5 r11i1p1f1
# Outputting future for CanESM5 r12i1p1f1
# Outputting future for CanESM5 r13i1p1f1
# Outputting future for CanESM5 r14i1p1f1
# Outputting future for CanESM5 r15i1p1f1
# Outputting future for CanESM5 r16i1p1f1
# Outputting future for CanESM5 r17i1p1f1
# Outputting future for CanESM5 r18i1p1f1
# Outputting future for CanESM5 r19i1p1f1
# Outputting future for CanESM5 r20i1p1f1
# Outputting future for CanESM5 r21i1p1f1
# Outputting future for CanESM5 r22i1p1f1
# Outputting future for CanESM5 r23i1p1f1
# Outputting future for CanESM5 r24i1p1f1
# Outputting future for CanESM5 r25i1p1f1
# Outputting past for CanESM5-CanOE r1i1p2f1
# Outputting past for CanESM5-CanOE r2i1p2f1
# Outputting past for CanESM5-CanOE r3i1p2f1
# Outputting future for CanESM5-CanOE r1i1p2f1
# Outputting future for CanESM5-CanOE r2i1p2f1
# Outputting future for CanESM5-CanOE r3i1p2f1
# Outputting past for CESM2 r1i1p1f1
# Outputting past for CESM2 r2i1p1f1
# Outputting past for CESM2 r3i1p1f1
# Outputting past for CESM2 r4i1p1f1
# Outputting past for CESM2 r5i1p1f1
# Outputting past for CESM2 r6i1p1f1
# Outputting past for CESM2 r7i1p1f1
# Outputting past for CESM2 r8i1p1f1
# Outputting past for CESM2 r9i1p1f1
# Outputting past for CESM2 r10i1p1f1
# Outputting future for CESM2 r1i1p1f1
# Outputting future for CESM2 r2i1p1f1
# Outputting past for CESM2-WACCM r1i1p1f1
# Outputting past for CESM2-WACCM r2i1p1f1
# Outputting past for CESM2-WACCM r3i1p1f1
# Outputting future for CESM2-WACCM r1i1p1f1
# Outputting past for CIESM r1i1p1f1
# Outputting past for CIESM r2i1p1f1
# Outputting past for CIESM r3i1p1f1
# Outputting future for CIESM r1i1p1f1
# Outputting past for CMCC-CM2-SR5 r1i1p1f1
# Outputting future for CMCC-CM2-SR5 r1i1p1f1
# Outputting past for CNRM-CM6-1 r1i1p1f2
# Outputting past for CNRM-CM6-1 r2i1p1f2
# Outputting past for CNRM-CM6-1 r3i1p1f2
# Outputting past for CNRM-CM6-1 r4i1p1f2
# Outputting past for CNRM-CM6-1 r5i1p1f2
# Outputting past for CNRM-CM6-1 r6i1p1f2
# Outputting past for CNRM-CM6-1 r7i1p1f2
# Outputting past for CNRM-CM6-1 r8i1p1f2
# Outputting past for CNRM-CM6-1 r9i1p1f2
# Outputting past for CNRM-CM6-1 r10i1p1f2
# Outputting past for CNRM-CM6-1 r11i1p1f2
# Outputting past for CNRM-CM6-1 r12i1p1f2
# Outputting past for CNRM-CM6-1 r13i1p1f2
# Outputting past for CNRM-CM6-1 r14i1p1f2
# Outputting past for CNRM-CM6-1 r15i1p1f2
# Outputting future for CNRM-CM6-1 r1i1p1f2
# Outputting future for CNRM-CM6-1 r2i1p1f2
# Outputting future for CNRM-CM6-1 r3i1p1f2
# Outputting future for CNRM-CM6-1 r4i1p1f2
# Outputting future for CNRM-CM6-1 r5i1p1f2
# Outputting future for CNRM-CM6-1 r6i1p1f2
# Outputting past for CNRM-CM6-1-HR r1i1p1f2
# Outputting future for CNRM-CM6-1-HR r1i1p1f2
# Outputting past for CNRM-ESM2-1 r1i1p1f2
# Outputting past for CNRM-ESM2-1 r2i1p1f2
# Outputting past for CNRM-ESM2-1 r3i1p1f2
# Outputting past for CNRM-ESM2-1 r4i1p1f2
# Outputting past for CNRM-ESM2-1 r5i1p1f2
# Outputting future for CNRM-ESM2-1 r1i1p1f2
# Outputting future for CNRM-ESM2-1 r2i1p1f2
# Outputting future for CNRM-ESM2-1 r3i1p1f2
# Outputting future for CNRM-ESM2-1 r4i1p1f2
# Outputting future for CNRM-ESM2-1 r5i1p1f2
# Outputting past for EC-Earth3 r1i1p1f1
# Outputting past for EC-Earth3 r2i1p1f1
# Outputting past for EC-Earth3 r3i1p1f1
# Outputting past for EC-Earth3 r4i1p1f1
# Outputting past for EC-Earth3 r5i1p1f1
# Outputting past for EC-Earth3 r6i1p1f1
# Outputting past for EC-Earth3 r7i1p1f1
# Outputting past for EC-Earth3 r8i1p1f1
# Outputting past for EC-Earth3 r9i1p1f1
# Outputting past for EC-Earth3 r10i1p1f1
# Outputting future for EC-Earth3 r1i1p1f1
# Outputting future for EC-Earth3 r4i1p1f1
# Outputting future for EC-Earth3 r6i1p1f1
# Outputting future for EC-Earth3 r9i1p1f1
# Outputting future for EC-Earth3 r11i1p1f1
# Outputting future for EC-Earth3 r13i1p1f1
# Outputting future for EC-Earth3 r15i1p1f1
# Outputting past for EC-Earth3-Veg r1i1p1f1
# Outputting past for EC-Earth3-Veg r2i1p1f1
# Outputting past for EC-Earth3-Veg r3i1p1f1
# Outputting past for EC-Earth3-Veg r4i1p1f1
# Outputting future for EC-Earth3-Veg r1i1p1f1
# Outputting future for EC-Earth3-Veg r2i1p1f1
# Outputting future for EC-Earth3-Veg r4i1p1f1
# Outputting past for FGOALS-f3-L r1i1p1f1
# Outputting past for FGOALS-f3-L r2i1p1f1
# Outputting past for FGOALS-f3-L r3i1p1f1
# Outputting future for FGOALS-f3-L r1i1p1f1
# Outputting past for FGOALS-g3 r1i1p1f1
# Outputting past for FGOALS-g3 r2i1p1f1
# Outputting past for FGOALS-g3 r3i1p1f1
# Outputting future for FGOALS-g3 r1i1p1f1
# Outputting past for FIO-ESM-2-0 r1i1p1f1
# Outputting past for FIO-ESM-2-0 r2i1p1f1
# Outputting past for FIO-ESM-2-0 r3i1p1f1
# Outputting future for FIO-ESM-2-0 r1i1p1f1
# Outputting future for FIO-ESM-2-0 r2i1p1f1
# Outputting future for FIO-ESM-2-0 r3i1p1f1
# Outputting past for GFDL-CM4 r1i1p1f1
# Outputting future for GFDL-CM4 r1i1p1f1
# Outputting past for GFDL-ESM4 r1i1p1f1
# Outputting future for GFDL-ESM4 r1i1p1f1
# Outputting past for GISS-E2-1-G r1i1p1f1
# Outputting past for GISS-E2-1-G r2i1p1f1
# Outputting past for GISS-E2-1-G r3i1p1f1
# Outputting past for GISS-E2-1-G r4i1p1f1
# Outputting past for GISS-E2-1-G r5i1p1f1
# Outputting past for GISS-E2-1-G r6i1p1f1
# Outputting past for GISS-E2-1-G r7i1p1f1
# Outputting past for GISS-E2-1-G r8i1p1f1
# Outputting past for GISS-E2-1-G r9i1p1f1
# Outputting past for GISS-E2-1-G r10i1p1f1
# Outputting future for GISS-E2-1-G r1i1p1f2
# Outputting past for HadGEM3-GC31-LL r1i1p1f3
# Outputting past for HadGEM3-GC31-LL r2i1p1f3
# Outputting past for HadGEM3-GC31-LL r3i1p1f3
# Outputting past for HadGEM3-GC31-LL r4i1p1f3
# Outputting future for HadGEM3-GC31-LL r1i1p1f3
# Outputting future for HadGEM3-GC31-LL r2i1p1f3
# Outputting future for HadGEM3-GC31-LL r3i1p1f3
# Outputting past for HadGEM3-GC31-MM r1i1p1f3
# Outputting past for HadGEM3-GC31-MM r2i1p1f3
# Outputting past for HadGEM3-GC31-MM r3i1p1f3
# Outputting past for HadGEM3-GC31-MM r4i1p1f3
# Outputting future for HadGEM3-GC31-MM r1i1p1f3
# Outputting future for HadGEM3-GC31-MM r2i1p1f3
# Outputting future for HadGEM3-GC31-MM r3i1p1f3
# Outputting past for INM-CM4-8 r1i1p1f1
# Outputting future for INM-CM4-8 r1i1p1f1
# Outputting past for INM-CM5-0 r1i1p1f1
# Outputting past for INM-CM5-0 r2i1p1f1
# Outputting past for INM-CM5-0 r3i1p1f1
# Outputting past for INM-CM5-0 r4i1p1f1
# Outputting past for INM-CM5-0 r5i1p1f1
# Outputting past for INM-CM5-0 r6i1p1f1
# Outputting past for INM-CM5-0 r7i1p1f1
# Outputting past for INM-CM5-0 r8i1p1f1
# Outputting future for INM-CM5-0 r1i1p1f1
# Outputting past for IPSL-CM6A-LR r1i1p1f1
# Outputting past for IPSL-CM6A-LR r2i1p1f1
# Outputting past for IPSL-CM6A-LR r3i1p1f1
# Outputting past for IPSL-CM6A-LR r4i1p1f1
# Outputting past for IPSL-CM6A-LR r5i1p1f1
# Outputting past for IPSL-CM6A-LR r6i1p1f1
# Outputting past for IPSL-CM6A-LR r7i1p1f1
# Outputting past for IPSL-CM6A-LR r8i1p1f1
# Outputting past for IPSL-CM6A-LR r9i1p1f1
# Outputting past for IPSL-CM6A-LR r10i1p1f1
# Outputting past for IPSL-CM6A-LR r11i1p1f1
# Outputting past for IPSL-CM6A-LR r12i1p1f1
# Outputting past for IPSL-CM6A-LR r13i1p1f1
# Outputting past for IPSL-CM6A-LR r14i1p1f1
# Outputting past for IPSL-CM6A-LR r15i1p1f1
# Outputting past for IPSL-CM6A-LR r16i1p1f1
# Outputting past for IPSL-CM6A-LR r17i1p1f1
# Outputting past for IPSL-CM6A-LR r18i1p1f1
# Outputting past for IPSL-CM6A-LR r19i1p1f1
# Outputting past for IPSL-CM6A-LR r20i1p1f1
# Outputting past for IPSL-CM6A-LR r21i1p1f1
# Outputting past for IPSL-CM6A-LR r22i1p1f1
# Outputting past for IPSL-CM6A-LR r23i1p1f1
# Outputting past for IPSL-CM6A-LR r24i1p1f1
# Outputting past for IPSL-CM6A-LR r25i1p1f1
# Outputting past for IPSL-CM6A-LR r26i1p1f1
# Outputting past for IPSL-CM6A-LR r27i1p1f1
# Outputting past for IPSL-CM6A-LR r28i1p1f1
# Outputting past for IPSL-CM6A-LR r29i1p1f1
# Outputting past for IPSL-CM6A-LR r30i1p1f1
# Outputting past for IPSL-CM6A-LR r31i1p1f1
# Outputting past for IPSL-CM6A-LR r32i1p1f1
# Outputting future for IPSL-CM6A-LR r1i1p1f1
# Outputting past for KACE-1-0-G r1i1p1f1
# Outputting past for KACE-1-0-G r2i1p1f1
# Outputting past for KACE-1-0-G r3i1p1f1
# Outputting future for KACE-1-0-G r1i1p1f1
# Outputting past for MCM-UA-1-0 r1i1p1f1
# changing longitude --> lon, latitude --> lat
# Outputting future for MCM-UA-1-0 r1i1p1f2
# changing longitude --> lon, latitude --> lat
# Outputting past for MIROC6 r1i1p1f1
# Outputting past for MIROC6 r2i1p1f1
# Outputting past for MIROC6 r3i1p1f1
# Outputting past for MIROC6 r4i1p1f1
# Outputting past for MIROC6 r5i1p1f1
# Outputting past for MIROC6 r6i1p1f1
# Outputting past for MIROC6 r7i1p1f1
# Outputting past for MIROC6 r8i1p1f1
# Outputting past for MIROC6 r9i1p1f1
# Outputting past for MIROC6 r10i1p1f1
# Outputting future for MIROC6 r1i1p1f1
# Outputting future for MIROC6 r2i1p1f1
# Outputting future for MIROC6 r3i1p1f1
# Outputting past for MIROC-ES2L r1i1p1f2
# Outputting past for MIROC-ES2L r2i1p1f2
# Outputting past for MIROC-ES2L r3i1p1f2
# Outputting future for MIROC-ES2L r1i1p1f2
# Outputting past for MPI-ESM1-2-HR r1i1p1f1
# Outputting past for MPI-ESM1-2-HR r2i1p1f1
# Outputting past for MPI-ESM1-2-HR r3i1p1f1
# Outputting past for MPI-ESM1-2-HR r4i1p1f1
# Outputting past for MPI-ESM1-2-HR r5i1p1f1
# Outputting past for MPI-ESM1-2-HR r6i1p1f1
# Outputting past for MPI-ESM1-2-HR r7i1p1f1
# Outputting past for MPI-ESM1-2-HR r8i1p1f1
# Outputting past for MPI-ESM1-2-HR r9i1p1f1
# Outputting past for MPI-ESM1-2-HR r10i1p1f1
# Outputting future for MPI-ESM1-2-HR r1i1p1f1
# Outputting past for MPI-ESM1-2-LR r1i1p1f1
# Outputting past for MPI-ESM1-2-LR r2i1p1f1
# Outputting past for MPI-ESM1-2-LR r3i1p1f1
# Outputting past for MPI-ESM1-2-LR r4i1p1f1
# Outputting past for MPI-ESM1-2-LR r5i1p1f1
# Outputting past for MPI-ESM1-2-LR r6i1p1f1
# Outputting past for MPI-ESM1-2-LR r7i1p1f1
# Outputting past for MPI-ESM1-2-LR r8i1p1f1
# Outputting past for MPI-ESM1-2-LR r9i1p1f1
# Outputting past for MPI-ESM1-2-LR r10i1p1f1
# Outputting future for MPI-ESM1-2-LR r1i1p1f1
# Outputting past for MRI-ESM2-0 r1i1p1f1
# Outputting past for MRI-ESM2-0 r2i1p1f1
# Outputting past for MRI-ESM2-0 r3i1p1f1
# Outputting past for MRI-ESM2-0 r4i1p1f1
# Outputting past for MRI-ESM2-0 r5i1p1f1
# Outputting future for MRI-ESM2-0 r1i1p1f1
# Outputting past for NESM3 r1i1p1f1
# Outputting past for NESM3 r2i1p1f1
# Outputting past for NESM3 r3i1p1f1
# Outputting past for NESM3 r4i1p1f1
# Outputting past for NESM3 r5i1p1f1
# Outputting future for NESM3 r1i1p1f1
# Outputting future for NESM3 r2i1p1f1
# Outputting past for NorESM2-LM r1i1p1f1
# Outputting past for NorESM2-LM r2i1p1f1
# Outputting past for NorESM2-LM r3i1p1f1
# Outputting future for NorESM2-LM r1i1p1f1
# Outputting past for NorESM2-MM r1i1p1f1
# Outputting future for NorESM2-MM r1i1p1f1
# Outputting past for UKESM1-0-LL r1i1p1f2
# Outputting past for UKESM1-0-LL r2i1p1f2
# Outputting past for UKESM1-0-LL r3i1p1f2
# Outputting past for UKESM1-0-LL r4i1p1f2
# Outputting future for UKESM1-0-LL r1i1p1f2
# Outputting future for UKESM1-0-LL r2i1p1f2
# Outputting future for UKESM1-0-LL r3i1p1f2
# Outputting future for UKESM1-0-LL r4i1p1f2
# Outputting future for UKESM1-0-LL r8i1p1f2

# %%
tas1memp.to_netcdf(path=pathout+"globalmeantascmip6.nc")
tas1memf.to_netcdf(path=pathout+"globalmeantascmip6.nc", mode="a")
tasemp.to_netcdf(path=pathout+"globalmeantascmip6.nc", mode="a")
tasemf.to_netcdf(path=pathout+"globalmeantascmip6.nc", mode="a")
